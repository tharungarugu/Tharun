# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HR.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['salary'] = label_encoder.fit_transform(df['salary'])

# %%
df['Department']=label_encoder.fit_transform(df['Department'])

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#df=df.drop("D0epartment",axis=1)

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
import seaborn as sns
corr = df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True,square=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.countplot(x='left', hue='Department',data=df)
plt.title('Distribution of Employee Retention')
plt.show()

# %%
sns.countplot(x='salary', hue='left', data=df)
plt.title('Impact of Salary on Employee Retention')
plt.show()

# %%
sns.countplot(x='Department', hue='left', data=df)
plt.title('Impact of Department on Employee Retention')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Department'] = label_encoder.fit_transform(df['Department'])

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X=df.drop(columns="salary")
X
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
Y=df["salary"]
Y
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: salary, Length: 14999, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 9011                 0.17             0.76               4
# 4041                 0.29             0.77               3
# 10150                0.61             0.67               3
# 8941                 0.91             0.88               5
# 1028                 0.88             0.89               4
# ...                   ...              ...             ...
# 185                  0.40             0.46               2
# 9835                 0.51             0.85               2
# 8593                 0.36             0.39               3
# 3661                 0.78             0.79               5
# 63                   0.36             0.56               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 9011                    199                   5              0     0
# 4041                    164                   6              0     0
# ...

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 7311                 0.64             0.89               4
# 1083                 0.83             0.94               4
# 12412                0.45             0.53               2
# 14049                0.43             0.88               2
# 14089                0.68             0.66               3
# ...                   ...              ...             ...
# 12129                0.37             0.45               2
# 5488                 0.69             0.74               2
# 5158                 0.86             0.96               4
# 14330                0.40             0.46               2
# 2532                 0.75             0.87               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 7311                    146                   3              0     0
# 1083                    267                   5              0     1
# ...

# %% [markdown]
# from sklearn.preprocessing

# %%
#Standardizing the dataset to get apppropriate values and avoid the outliers
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
Scaler=scaler.fit(X_train)

# %%
X_train_scaled=scaler.transform(X_train)

# %%
Y_train_scaled=scaler.transform(X_test)

# %%
X_train_scaled.std()
# Out:
# 1.0

# %%
X_train_scaled
# Out:
# array([[ 0.34376958, -0.32842316, -0.66212694, ..., -0.55185842,
#         -0.14595719, -1.70569971],
#        [ 1.1851956 , -0.62014677,  0.15398843, ..., -0.55185842,
#         -0.14595719, -1.35563049],
#        [-0.2171811 , -1.90373065, -0.66212694, ..., -0.55185842,
#         -0.14595719, -0.65549204],
#        ...,
#        [ 0.18349796,  1.59695267,  0.9701038 , ..., -0.55185842,
#         -0.14595719,  1.09485409],
#        [-0.29731691, -1.14524926,  0.9701038 , ..., -0.55185842,
#         -0.14595719,  1.09485409],
#        [ 1.22526351,  0.78012656, -0.66212694, ..., -0.55185842,
#         -0.14595719,  0.39471564]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logi = LogisticRegression(random_state=0).fit(X_train_scaled, Y_train)

# %%
logi.predict(X_train_scaled)
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
#accuracy
logi.score(X_train_scaled,Y_train)
# Out:
# 0.506905419563768

# %%
logi.score(Y_train_scaled,Y_test)
# Out:
# 0.49755555555555553

# %%
a=df["Department"]

# %%
a
# Out:
# 0        7
# 1        7
# 2        7
# 3        7
# 4        7
#         ..
# 14994    8
# 14995    8
# 14996    8
# 14997    8
# 14998    8
# Name: Department, Length: 14999, dtype: int64

# %%
b=df["time_spend_company"]

# %%
b
# Out:
# 0        3
# 1        6
# 2        4
# 3        5
# 4        3
#         ..
# 14994    3
# 14995    3
# 14996    3
# 14997    4
# 14998    3
# Name: time_spend_company, Length: 14999, dtype: int64

# %%
logi.coef_
# Out:
# array([[-0.03399656, -0.04509322, -0.01701745,  0.04019319,  0.08799076,
#         -0.03159968, -0.4746911 ,  0.11764671, -0.07802547],
#        [ 0.01095266,  0.03121836,  0.0126938 , -0.02585994, -0.09695086,
#          0.03654041,  0.34536704, -0.14265729,  0.06051411],
#        [ 0.0230439 ,  0.01387486,  0.00432364, -0.01433325,  0.0089601 ,
#         -0.00494072,  0.12932406,  0.02501058,  0.01751136]])

# %%
logi.intercept_
# Out:
# array([-1.27771575,  0.69999215,  0.5777236 ])
